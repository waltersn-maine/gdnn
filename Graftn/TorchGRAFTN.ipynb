# %%
import numpy as np
import scipy.sparse as sp
import torch
import torch.nn as nn
from torch.optim import Adam
import matplotlib.pyplot as plt

# Confirm torch version and device
print(f'PyTorch version: {torch.__version__}')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# PyTorch version: 2.9.1+cu128
# Device: cuda

# %%
plt.rcParams.update({
    'font.size'      : 20,
    'font.weight'    : 'bold',
    'axes.titlesize' : 14,
    'axes.labelsize' : 13,
    'axes.labelweight': 'bold',
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'figure.titlesize': 15
})

# %%
# Features and targets
X_norm       = np.load('data/X_norm_clean.npy')
R            = np.load('data/spec5refl_R.npy')
E            = np.load('data/endmem21_E.npy')
valid_mask   = np.load('data/spectral_valid_mask.npy')

# Spatial Laplacians
L_elev   = sp.load_npz('data/L_elev.npz')
L_aspect = sp.load_npz('data/L_aspect.npz')
L_ddem   = sp.load_npz('data/L_ddem.npz')

# Spectral Laplacian
L_band = np.load('data/L_band.npy')

print(f'X_norm       : {X_norm.shape}   dtype={X_norm.dtype}')
print(f'R            : {R.shape}   dtype={R.dtype}')
print(f'E            : {E.shape}   dtype={E.dtype}')
print(f'valid_mask   : {valid_mask.shape}  dtype={valid_mask.dtype}')
print(f'L_elev       : {L_elev.shape}  nnz={L_elev.nnz:,}')
print(f'L_aspect     : {L_aspect.shape}  nnz={L_aspect.nnz:,}')
print(f'L_ddem       : {L_ddem.shape}  nnz={L_ddem.nnz:,}')
print(f'L_band       : {L_band.shape}')
# Out:
# X_norm       : (2041172, 12)   dtype=float32
# R            : (2041172, 5)   dtype=float32
# E            : (21, 5)   dtype=float32
# valid_mask   : (2041172,)  dtype=bool
# L_elev       : (2041172, 2041172)  nnz=18,345,196
# L_aspect     : (2041172, 2041172)  nnz=18,347,260
# L_ddem       : (2041172, 2041172)  nnz=18,267,646
# L_band       : (5, 5)

# %% [markdown]
# # Rebuild normalized feature matrix dropping log_accum (topo col index 5)
# # X_norm columns:
# #   0-4  : spectral (Blue, Green, Red, RedEdge, NIR)
# #   5-10 : topo (elevation, slope, asin, acos, curvature, log_accum)
# #   11   : panchromatic
# #   12   : LWIR
# # Drop col 10 (log_accum)
#
# keep_cols = list(range(10)) + [11, 12]   # drop index 10
# X_norm_clean = X_norm[:, keep_cols]
#
# print(f'X_norm_clean shape: {X_norm_clean.shape}  (dropped log_accum)')
# print()
#
# # Verify log_accum is gone and no extreme values remain
# col_names_clean = ['Blue', 'Green', 'Red', 'RedEdge', 'NIR',
#                    'elevation', 'slope', 'aspect_sin', 'aspect_cos',
#                    'curvature', 'panchromatic', 'lwir']
# print(f'{"Feature":>14}  {"Min":>12}  {"Max":>12}  {"NaNs":>8}')
# print('-' * 54)
# for i, name in enumerate(col_names_clean):
#     col = X_norm_clean[:, i]
#     nans = np.isnan(col).sum()
#     valid = col[~np.isnan(col)]
#     print(f'{name:>14}  {valid.min():>12.4f}  {valid.max():>12.4f}  {nans:>8,}')
#
# print()

# %% [markdown]
# # Zero out NaN rows (boundary fringe pixels)
# # These are excluded from reconstruction loss by mask anyway
# nan_rows = np.isnan(X_norm_clean).any(axis=1)
# X_norm_clean[nan_rows] = 0.0
# print(f'Zeroed {nan_rows.sum():,} NaN rows')
# print(f'Remaining NaNs: {np.isnan(X_norm_clean).sum()}')
#
# # Save updated feature matrix
# np.save('data/X_norm_clean.npy', X_norm_clean)
# print('Saved data/X_norm_clean.npy')

# %%
# GPU memory available
if torch.cuda.is_available():
    gpu_mem_total = torch.cuda.get_device_properties(0).total_memory / 1e9
    gpu_mem_free  = torch.cuda.mem_get_info()[0] / 1e9
    print(f'GPU: {torch.cuda.get_device_properties(0).name}')
    print(f'  Total memory : {gpu_mem_total:.1f} GB')
    print(f'  Free memory  : {gpu_mem_free:.1f} GB')
    print()

# Estimate memory footprint of key arrays
def mem_mb(arr):
    return arr.nbytes / 1e6

print('CPU array sizes:')
print(f'  X_norm         : {mem_mb(X_norm):.1f} MB')
print(f'  R              : {mem_mb(R):.1f} MB')
print(f'  E              : {mem_mb(E):.3f} MB')
print()

# Sparse Laplacian memory (data + indices)
def sparse_mem_mb(L):
    return (L.data.nbytes + L.indices.nbytes + L.indptr.nbytes) / 1e6

print('Sparse Laplacian sizes (CSR):')
print(f'  L_elev         : {sparse_mem_mb(L_elev):.1f} MB')
print(f'  L_aspect       : {sparse_mem_mb(L_aspect):.1f} MB')
print(f'  L_ddem         : {sparse_mem_mb(L_ddem):.1f} MB')
print()

# Estimate A matrix (memberships) size
N, K = X_norm.shape[0], E.shape[0]
A_size_mb = N * K * 4 / 1e6   # float32
print(f'A matrix (N={N}, K={K}): {A_size_mb:.1f} MB')
print()
print(f'Estimated total GPU requirement: '
      f'{mem_mb(X_norm) + mem_mb(R) + 3*sparse_mem_mb(L_elev) + A_size_mb:.1f} MB')
# Out:
# GPU: NVIDIA RTX 4500 Ada Generation
#   Total memory : 24.2 GB
#   Free memory  : 22.8 GB
#
# CPU array sizes:
#   X_norm         : 98.0 MB
#   R              : 40.8 MB
#   E              : 0.000 MB
#
# Sparse Laplacian sizes (CSR):
#   L_elev         : 228.3 MB
#   L_aspect       : 228.3 MB
#   L_ddem         : 227.4 MB
#
# A matrix (N=2041172, K=21): 171.5 MB
#
# Estimated total GPU requirement: 995.2 MB

# %%
# convert dense arrays to torch tensors on GPU
X      = torch.tensor(X_norm, dtype=torch.float32, device=device)
R_tens = torch.tensor(R,      dtype=torch.float32, device=device)
E_tens = torch.tensor(E,       dtype=torch.float32, device=device)
mask   = torch.tensor(valid_mask, dtype=torch.bool, device=device)
L_band_tens = torch.tensor(L_band, dtype=torch.float32, device=device)

print(f'X      : {X.shape}  {X.device}')
print(f'R      : {R_tens.shape}  {R_tens.device}')
print(f'E      : {E_tens.shape}  {E_tens.device}')
print(f'mask   : {mask.shape}  {mask.device}')
print(f'L_band : {L_band_tens.shape}  {L_band_tens.device}')
print()
# Out:
# X      : torch.Size([2041172, 12])  cuda:0
# R      : torch.Size([2041172, 5])  cuda:0
# E      : torch.Size([21, 5])  cuda:0
# mask   : torch.Size([2041172])  cuda:0
# L_band : torch.Size([5, 5])  cuda:0

# %%
# convert sparse scipy CSR matrices to torch sparse CSR tensors on GPU
def scipy_csr_to_torch_sparse(L, device):
    """convert scipy csr sparse matrix to torch sparse csr tensor"""
    L = L.astype(np.float32)
    crow_indices = torch.tensor(L.indptr,  dtype=torch.int32)
    col_indices  = torch.tensor(L.indices, dtype=torch.int32)
    values       = torch.tensor(L.data,    dtype=torch.float32)
    size         = L.shape
    return torch.sparse_csr_tensor(
        crow_indices, col_indices, values,
        size=size, dtype=torch.float32
    ).to(device)

# %%
print("converting spatial laplacians to torch sparse csr...")
L_elev_t = scipy_csr_to_torch_sparse(L_elev, device)
L_aspect_t = scipy_csr_to_torch_sparse(L_aspect, device)
L_ddem_t = scipy_csr_to_torch_sparse(L_ddem, device)

print(f'L_elev   : {L_elev_t.shape} {L_elev_t.device}')
print(f'L_aspect : {L_aspect_t.shape} {L_aspect_t.device}')
print(f'L_ddem_t : {L_ddem_t.shape} {L_ddem_t.device}')

# report GPU memory after loading 
mem_used = (torch.cuda.memory_allocated() / 1e9)
mem_free = (torch.cuda.mem_get_info()[0] / 1e9)
print(f'gpu memory allocated : {mem_used:.2f} GB')
print(f'gpu memory free      : {mem_free:.2f} GB')
# Out:
# converting spatial laplacians to torch sparse csr...
# /tmp/ipykernel_76842/1075959278.py:9: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   return torch.sparse_csr_tensor(
# L_elev   : torch.Size([2041172, 2041172]) cuda:0
# L_aspect : torch.Size([2041172, 2041172]) cuda:0
# L_ddem_t : torch.Size([2041172, 2041172]) cuda:0
# gpu memory allocated : 0.61 GB
# gpu memory free      : 22.18 GB

# %%
# CPD (canonical polyadic decomposition) Tensor Layer
class CPDTensorLayer(nn.Module):
    """
    rank-R canonical polyadic decomposition (CPD) tensor layer
    mapping (spectral + topo) -> hidden

    Input:
        x_i ∈ ℝ^{D_in} split into:
            s_i ∈ ℝ^{D_s} (spectral, first D_s features (here 5 bands))
            t_i ∈ ℝ^{D_t} (topographic+aux, remaining features (here 6 topo + 2 aux bands)

    Weight tensor:
        W ∈ ℝ^{D_s x D_t x D_out} in rank-R CPD format:
        W = Σ_r (u_r^(1) ⊗ u_r^(2) ⊗ u_r^(3))

        where ⊗ := outer product
        and u_r^(*) is the r-th decomposition vector of U(*)

    Factor matrices:
        U1 ∈ ℝ^{D_s  x R}   spectral mode -- regularized by L_band
        U2 ∈ ℝ^{D_t  x R}   topographic mode 
        U3 ∈ ℝ^{D_out  x R} output mode

        'mode' in the tensor sense
        R (hyperparameter) CPD rank: 
            number of rank-1 terms in the decomposition
            controls how expressive the weight tensor is
        D_out (hyperparameter) output dimension of the tensor layer:
            determines dimensionality of the hidden space
            that passes to the attention layer
        

    Forward pass -- (tensor) efficient: never builds full W:
        h_i = Σ_r (s_i · u_r^(1)) * (t_i · u_r^(2)) * u_r^(3)
            = U3 · ((U1ᵀ s_i) * (U2ᵀ t_i))
            outputs a vector of length D_out
            note: 1st line '·' = vector inner product
                           '*' = scalar multiplication
                  2nd line '.' = matrix-vector product
                           '*' = element-wise vector multiplication
        
    """
    
    def __init__(self, D_s, D_t, D_out, R):
        super().__init__()
        self.D_s = D_s
        self.D_t = D_t
        self.R   = R

        # CPD factor matrices
        self.U1 = nn.Parameter(torch.empty(D_s,   R))
        self.U2 = nn.Parameter(torch.empty(D_t,   R))
        self.U3 = nn.Parameter(torch.empty(D_out, R))

        #initialize with small random values
        nn.init.xavier_normal_(self.U1)
        nn.init.xavier_normal_(self.U2)
        nn.init.xavier_normal_(self.U3)

        self.norm = nn.LayerNorm(D_out)


    def forward(self, x):
        """
        x : (N, D_s + D_t)
        returns h : (N, D_out)
        """
        s = x[:, :self.D_s]        # (N, D_s)
        t = x[:, self.D_s:]        # (N, D_t)

        # project each mode onto its factor matrix
        # (N, D_s) @ (D_s, R) -> (N, R)
        alpha = s @ self.U1      # spectral projections
        # (N, D_t) @ (D_t, R) -> (N, R)
        beta  = t @ self.U2      # topo projections

        # element-wise product of mode projections
        # (N, R) * (N, R) -> (N, R)
        gamma = alpha * beta

        # project to output dimension
        # (N, R) @ (R, D_out) -> (N, D_out)
        h = gamma @ self.U3.T

        return torch.relu(self.norm(h))


    def band_regularization(self, L_band):
        """
        Graph Laplacian regularization on spectral factor matrix U1
        tr(U1ᵀ L_band U1) -- encourages spectrally similar bands
                            to have similar factor vectors
        L_band : (D_s, D_s) -- dense tensor
        """
        return torch.trace(self.U1.T @ L_band @ self.U1)

print('CPDTensorLayer defined')
# Out:
# CPDTensorLayer defined

# %%
### cross-modal attention module ###
# graph-laplacian regularization approximates INTRA-modal attention
# by encouraging smoothness within a mode
## cross-modal attention is between the CPD hidden representation
# and the raw input features

class CrossModalAttention(nn.Module):
    """
    cross-modal attention between the CPD hidden representation
    and the raw input features

    Query   : from CPD hidden h ∈ ℝ^{D_hidden}
    Key     : from raw input  x ∈ ℝ^{D_in}
    Value   : from raw input  x ∈ ℝ^{D_in}

    Learns which input features are most informative
        given the joint spectral-topographic representation.
    Residual connection added for training stability
    """
    def __init__(self, D_hidden, D_in, D_attn):
        super().__init__()
        self.D_attn = D_attn
        self.scale  = D_attn ** -0.5

        self.W_Q = nn.Linear(D_hidden, D_attn, bias=False)
        self.W_K = nn.Linear(D_in,     D_attn, bias=False)
        self.W_V = nn.Linear(D_in,     D_attn, bias=False)

        # project attention output back to D_hidden for residual
        self.W_O = nn.Linear(D_attn, D_hidden, bias=False)

        self.norm = nn.LayerNorm(D_hidden)

    def forward(self, h, x):
        """
        h : (N, D_hidden) CPD layer output
        x : (N, D_in)     raw normalized input
        returns h' : (N, D_hidden)
        """
        Q = self.W_Q(h)        # (N, D_attn)
        K = self.W_K(x)        # (N, D_attn)
        V = self.W_V(x)        # (N, D_attn)

        # per-pixel self-attention score (scalar per pixel)
        # each pixel attends to its features only --- 
        # no cross-pixel attention (that would be O(N^2))
        # spatial structure is "attended" by the laplacians
        attn = torch.sum(Q * K, dim=1, keepdim=True) * self.scale
        attn = torch.sigmoid(attn)   # (N, 1)

        # weighted value
        out = attn * V          # (N, D_attn)
        out = self.W_O(out)     # (N, D_hidden)

        # residual + LayerNorm
        return self.norm(h + out)

print('CrossModalAttention defined')
# Out:
# CrossModalAttention defined

# %%
### FULL MODEL ###
class GRAFTN(nn.Module):
    """
    Graph-Regularized Attention Fuzzy Tensor Network

    Architecture:
        1. CPD Tensor Layer  : (spectral x topo) -> hidden
        2. Cross-Modal Attn  : refine hidden using raw input
        3. Membership Head   : hidden -> sigmoid -> [0,1]^k
        where k := number of endmembers to unmix into

    Loss (computed externally):
        reconstruction ||R - A·Eᵀ||²
        + spatial smoothness 
                λ^(*)·tr(AᵀL_(*) A) 
                where (*) ∈ {elev, aspect, ddem}
        + spectral factor smoothness
                λ^(band)·tr(AᵀL_(band) A)
    """

    def __init__(self,
                 D_s=5,     # spectral input dim
                 D_t=8,     # topo+aux input dim
                 D_out=32,  # CPD output (hidden) dim
                 R=8,       # CPD rank
                 D_attn=16, # attention dim
                 k=21):     # number of endmembers
        super().__init__()

        self.D_s = D_s
        self.D_t = D_t
        D_in = D_s + D_t

        # CPD tensor layer
        self.cpd = CPDTensorLayer(D_s, D_t, D_out, R)

        # Cross-modal attention
        self.attn = CrossModalAttention(D_out, D_in, D_attn)

        # Membership head
        self.head = nn.Sequential(
            nn.Linear(D_out, k),
            nn.Sigmoid()
        )

    def forward(self, x):
        """
        x : (N, D_s + D_t) normalized input features
        returns a : (N, k) fuzzy memberships in [0, 1]
        """
        h  = self.cpd(x)      # (N, D_out)
        h  = self.attn(h, x)  # (N, D_out)
        a  = self.head(h)     # (N, k)

        return a

    def band_regularization(self, L_band):
        return self.cpd.band_regularization(L_band)

print('GRAFTN defined')
# Out:
# GRAFTN defined

# %%
### build loss function ###
def graftn_loss(A, X, R_tens, E_tens, mask,
                L_elev_t, L_aspect_t, L_ddem_t,
                L_band_tens, model,
                lam_elev, lam_aspect, lam_ddem, lam_band):
    """
    GRAFTN loss function

    Terms:
        1. Spectral reconstruction  : ||R_valid - A_valid @ E^T||^2_F
        2. Elevation smoothness     : lambda_elev   * tr(A^T L_elev   A)
        3. Aspect smoothness        : lambda_aspect * tr(A^T L_aspect A)
        4. dDEM smoothness          : lambda_ddem   * tr(A^T L_ddem   A)
        5. Band factor smoothness   : lambda_band   * tr(U1^T L_band U1)

    Parameters
    ----------
    A          : (N, k) membership matrix, output of model
    X          : (N, 13) normalized input features
    R_tens     : (N, 5) raw reflectance (mosaic values)
    E_tens     : (k, 5) endmember matrix
    mask       : (N,) bool -- pixels with valid spectral values
    L_*_t      : (N, N) sparse torch CSR Laplacians (elev, aspect, ddem)
    L_band_tens: (5, 5) dense spectral Laplacian
    model      : GRAFTN instance (for band regularization)
    lam_*      : scalar regularization weights (lambda)

    Returns
    --------
    loss_total, loss_recon, loss_spatial, loss_band
    """

    # ----- 1. Spectral reconstruction loss ----
    # only over spectrally valid pixels
    A_valid = A[mask]          # (N_valid, k)
    R_valid = R_tens[mask]     # (N_valid, k)

    # Predicted reflectance: A_valid @ E^T shape (N_valid, 5)
    # Divide E by k so uniform memberships ~0.5 produce
    # predicted reflectance at correct magnitude
    k = E_tens.shape[0]
    R_pred = A_valid @ (E_tens / k)
    # R_pred = A_valid @ E_tens  # (N_valid, 5) # previous

    # Frobenius norm squared, normalized by number of valid pixels
    loss_recon = torch.sum((R_valid - R_pred) ** 2) / mask.sum()


    # ----- 2. Spatial smoothness losses ---
    # tr(A^T L A) = sum_ij w_ij(a_i - a_j)^2
    # compute efficiently as tr(A^T (L A))
    # L is sparse (N,N), A is dense (N,k)
    # torch.mm not supported for sparse @ dense in all versions
    # use torch.sparse.mm instead

    LA_elev   = torch.sparse.mm(L_elev_t,   A) # (N, k)
    LA_aspect = torch.sparse.mm(L_aspect_t, A) # (N, k)
    LA_ddem   = torch.sparse.mm(L_ddem_t,   A) # (N, k)

    # tr(A^T LA) = sum of element-wise product of A * LA
    loss_elev    = torch.sum(A * LA_elev)   / A.shape[0]
    loss_aspect  = torch.sum(A * LA_aspect) / A.shape[0]
    loss_ddem    = torch.sum(A * LA_ddem)   / A.shape[0]

    loss_spatial = (lam_elev   * loss_elev +
                    lam_aspect * loss_aspect +
                    lam_ddem   * loss_ddem)

    # ------ 3. Band factor regularization --- 
    loss_band = lam_band * model.band_regularization(L_band_tens)

    # ------ 4. Total ----
    loss_total = loss_recon + loss_spatial + loss_band

    return loss_total, loss_recon, loss_spatial, loss_band

print('graftn_loss defined')
# Out:
# graftn_loss defined

# %%
# instantiate and move to device
model = GRAFTN(
    D_s=5, D_t=7, D_out=32, R=8, D_attn=16, k=21 # D_t = 7 -- removed log_acc
).to(device)

# %%
# parameter count
total_params = sum(p.numel() for p in model.parameters())
print(f'model parameters: {total_params:,}')
print()
for name, p in model.named_parameters():
    print(f' {name:<30} {str(p.shape):<25} {p.numel():>6,}')
# Out:
# model parameters: 2,581
#
#  cpd.U1                         torch.Size([5, 8])            40
#  cpd.U2                         torch.Size([7, 8])            56
#  cpd.U3                         torch.Size([32, 8])          256
#  cpd.norm.weight                torch.Size([32])              32
#  cpd.norm.bias                  torch.Size([32])              32
#  attn.W_Q.weight                torch.Size([16, 32])         512
#  attn.W_K.weight                torch.Size([16, 12])         192
#  attn.W_V.weight                torch.Size([16, 12])         192
#  attn.W_O.weight                torch.Size([32, 16])         512
#  attn.norm.weight               torch.Size([32])              32
#  attn.norm.bias                 torch.Size([32])              32
#  head.0.weight                  torch.Size([21, 32])         672
#  head.0.bias                    torch.Size([21])              21

# %%
#### Training Loop ####

# %%
# hyperparameters 
LEARNING_RATE = 1e-3
N_EPOCHS      = 100
LOG_EVERY     = 10 # print loss every * epochs

# regularization weights
# reconstruction loss normalized by N_valid (~1.99M pixels)
# spatial losses normalized by N (~2.04M pixels)
# band loss is a small scalar -- lam_band can be larger
# using empirically derived values
LAM_ELEV    = 1.0
LAM_ASPECT  = 0.65
LAM_DDEM    = 0.78
LAM_BAND    = 0.014

optimizer = Adam(model.parameters(), lr=LEARNING_RATE)

# training history
history = {
    'total':[], 'recon':[], 'spatial':[], 'band':[]
}

print('GRAFTN Training')
print(f'  Epochs        : {N_EPOCHS}')
print(f'  Learning rate : {LEARNING_RATE}')
print(f'  lam_elev      : {LAM_ELEV}')
print(f'  lam_aspect    : {LAM_ASPECT}')
print(f'  lam_ddem      : {LAM_DDEM}')
print(f'  lam_band      : {LAM_BAND}')
print()

import time
t_start = time.time()

for epoch in range(1, N_EPOCHS + 1):
    model.train()
    optimizer.zero_grad()

    # forward pass -- all N pixels at once
    A = model(X)   # (N, k)

    # loss 
    loss_total, loss_recon, loss_spatial, loss_band = graftn_loss(
        A, X, R_tens, E_tens, mask,
        L_elev_t, L_aspect_t, L_ddem_t,
        L_band_tens, model,
        LAM_ELEV, LAM_ASPECT, LAM_DDEM, LAM_BAND
    )

    # backward pass
    loss_total.backward()
    optimizer.step()

    # record history
    history['total'].append(loss_total.item())
    history['recon'].append(loss_recon.item())
    history['spatial'].append(loss_spatial.item())
    history['band'].append(loss_band.item())

    if epoch % LOG_EVERY == 0 or epoch == 1:
        elapsed = time.time() - t_start
        print(f'Epoch {epoch:>4d}/{N_EPOCHS}  '
              f'total={loss_total.item():.6f}  '
              f'recon={loss_recon.item():.6f}  '
              f'spatial={loss_spatial.item():.6f}  '
              f'band={loss_band.item():.6f}  '
              f'({elapsed:.1f}s)')

print()
print(f'training complete in {time.time()-t_start:.1f} s')
# Out:
# GRAFTN Training
#   Epochs        : 100
#   Learning rate : 0.001
#   lam_elev      : 1.0
#   lam_aspect    : 0.65
#   lam_ddem      : 0.78
#   lam_band      : 0.014
#
# Epoch    1/100  total=0.446636  recon=0.116109  spatial=0.252082  band=0.078444  (17.1s)
# Epoch   10/100  total=0.382524  recon=0.112305  spatial=0.194433  band=0.075786  (456.6s)
# Epoch   20/100  total=0.336723  recon=0.107907  spatial=0.156060  band=0.072756  (791.1s)
# Epoch   30/100  total=0.307551  recon=0.103887  spatial=0.133976  band=0.069689  (1145.8s)
# Epoch   40/100  total=0.287724  recon=0.100456  spatial=0.120581  band=0.066686  (1507.4s)
# Epoch   50/100  total=0.273386  recon=0.097548  spatial=0.112037  band=0.063802  (1869.6s)
# Epoch   60/100  total=0.262111  recon=0.094952  spatial=0.106111  band=0.061048  (2232.7s)
# Epoch   70/100  total=0.252630  recon=0.092519  spatial=0.101689  band=0.058423  (2598.4s)
# Epoch   80/100  total=0.244563  recon=0.090249  spatial=0.098396  band=0.055918  (2959.5s)
# Epoch   90/100  total=0.237661  recon=0.087990  spatial=0.096143  band=0.053529  (3320.7s)
# Epoch  100/100  total=0.231614  recon=0.085852  spatial=0.094514  band=0.051248  (3684.0s)
#
# training complete in 3684.0 s

# %%
model_test = GRAFTN(
    D_s=5, D_t=7, D_out=32, R=8, D_attn=16, k=21
).to(device)

with torch.no_grad():
    A_test = model_test(X)

print('A_test stats:')
print(f'  shape : {A_test.shape}')
print(f'  min   : {A_test.min().item():.6f}')
print(f'  max   : {A_test.max().item():.6f}')
print(f'  mean  : {A_test.mean().item():.6f}')
print(f'  NaNs  : {torch.isnan(A_test).sum().item()}')
print(f'  Infs  : {torch.isinf(A_test).sum().item()}')
print()

# Check each layer output individually
with torch.no_grad():
    # CPD layer
    h_cpd = model_test.cpd(X)
    print(f'CPD output:')
    print(f'  NaNs: {torch.isnan(h_cpd).sum().item()}')
    print(f'  Infs: {torch.isinf(h_cpd).sum().item()}')
    print(f'  min : {h_cpd.min().item():.4f}')
    print(f'  max : {h_cpd.max().item():.4f}')
    print()

    # Attention layer
    h_attn = model_test.attn(h_cpd, X)
    print(f'Attention output:')
    print(f'  NaNs: {torch.isnan(h_attn).sum().item()}')
    print(f'  Infs: {torch.isinf(h_attn).sum().item()}')
    print(f'  min : {h_attn.min().item():.4f}')
    print(f'  max : {h_attn.max().item():.4f}')
    print()

    # Membership head
    a_head = model_test.head(h_attn)
    print(f'Head output:')
    print(f'  NaNs: {torch.isnan(a_head).sum().item()}')
    print(f'  Infs: {torch.isinf(a_head).sum().item()}')
    print(f'  min : {a_head.min().item():.4f}')
    print(f'  max : {a_head.max().item():.4f}')
    print()

    # Reconstruction loss alone
    A_valid = A_test[mask]
    R_valid = R_tens[mask]
    R_pred  = A_valid @ E_tens
    loss_recon = torch.sum((R_valid - R_pred)**2) / mask.sum()
    print(f'Reconstruction loss: {loss_recon.item():.6f}')
    print(f'  R_pred NaNs: {torch.isnan(R_pred).sum().item()}')
    print()

    # Spatial loss -- check sparse mm output
    LA = torch.sparse.mm(L_elev_t, A_test)
    print(f'Sparse mm (L_elev @ A):')
    print(f'  NaNs: {torch.isnan(LA).sum().item()}')
    print(f'  Infs: {torch.isinf(LA).sum().item()}')
    print(f'  min : {LA.min().item():.4f}')
    print(f'  max : {LA.max().item():.4f}')
# Out:
# A_test stats:
#   shape : torch.Size([2041172, 21])
#   min   : 0.087444
#   max   : 0.917582
#   mean  : 0.493679
#   NaNs  : 0
#   Infs  : 0
#
# CPD output:
#   NaNs: 0
#   Infs: 0
#   min : 0.0000
#   max : 3.5484
#
# Attention output:
#   NaNs: 0
#   Infs: 0
#   min : -2.5593
#   max : 4.7689
#
# Head output:
#   NaNs: 0
#   Infs: 0
#   min : 0.0874
#   max : 0.9176
#
# Reconstruction loss: 46.757233
#   R_pred NaNs: 0
#
# Sparse mm (L_elev @ A):
#   NaNs: 0
#   Infs: 0
#   min : -0.6457
#   max : 0.8800

# %%
with torch.no_grad():
    s = X[:, :5]        # (N, 5)
    t = X[:, 5:]        # (N, 8)

    U1 = model_test.cpd.U1
    U2 = model_test.cpd.U2
    U3 = model_test.cpd.U3

    alpha = s @ U1      # (N, R)
    beta  = t @ U2      # (N, R)
    gamma = alpha * beta # (N, R)
    h_pre = gamma @ U3.T # (N, D_out)

    print('Pre-LayerNorm stats:')
    print(f'  NaNs : {torch.isnan(h_pre).sum().item()}')
    print(f'  Infs : {torch.isinf(h_pre).sum().item()}')
    print(f'  min  : {h_pre.min().item():.6f}')
    print(f'  max  : {h_pre.max().item():.6f}')
    print(f'  mean : {h_pre.mean().item():.6f}')
    print(f'  std  : {h_pre.std().item():.6f}')
    print()

    # Check variance per row -- LayerNorm divides by per-row std
    row_std = h_pre.std(dim=1)
    print(f'Per-row std stats:')
    print(f'  min  : {row_std.min().item():.8f}')
    print(f'  max  : {row_std.max().item():.8f}')
    print(f'  mean : {row_std.mean().item():.8f}')
    print(f'  zero rows: {(row_std == 0).sum().item()}')
    print(f'  near-zero rows (< 1e-5): {(row_std < 1e-5).sum().item()}')
    print()

    # Check intermediate steps
    print('Alpha stats:')
    print(f'  NaNs: {torch.isnan(alpha).sum().item()}')
    print(f'  min : {alpha.min().item():.6f}  max: {alpha.max().item():.6f}')
    print()
    print('Beta stats:')
    print(f'  NaNs: {torch.isnan(beta).sum().item()}')
    print(f'  min : {beta.min().item():.6f}  max: {beta.max().item():.6f}')
    print()
    print('Gamma stats:')
    print(f'  NaNs: {torch.isnan(gamma).sum().item()}')
    print(f'  min : {gamma.min().item():.6f}  max: {gamma.max().item():.6f}')
# Out:
# Pre-LayerNorm stats:
#   NaNs : 0
#   Infs : 0
#   min  : -31.480423
#   max  : 16.455154
#   mean : 0.006312
#   std  : 0.638937
#
# Per-row std stats:
#   min  : 0.00000000
#   max  : 11.45674992
#   mean : 0.49504891
#   zero rows: 52926
#   near-zero rows (< 1e-5): 52926
#
# Alpha stats:
#   NaNs: 0
#   min : -8.583163  max: 6.135272
#
# Beta stats:
#   NaNs: 0
#   min : -9.427881  max: 9.946370
#
# Gamma stats:
#   NaNs: 0
#   min : -16.425812  max: 50.140598

# %%
with torch.no_grad():
    s = X[:, :5]
    t = X[:, 5:]

    print('s (spectral input) stats:')
    print(f'  NaNs: {torch.isnan(s).sum().item()}')
    print(f'  Infs: {torch.isinf(s).sum().item()}')
    print(f'  min : {s[~torch.isnan(s)].min().item():.6f}')
    print(f'  max : {s[~torch.isnan(s)].max().item():.6f}')
    print()

    print('t (topo input) stats:')
    print(f'  NaNs: {torch.isnan(t).sum().item()}')
    print(f'  Infs: {torch.isinf(t).sum().item()}')
    print(f'  min : {t[~torch.isnan(t)].min().item():.6f}')
    print(f'  max : {t[~torch.isnan(t)].max().item():.6f}')
    print()

    print('U1 stats:')
    print(f'  NaNs: {torch.isnan(model_test.cpd.U1).sum().item()}')
    print(f'  min : {model_test.cpd.U1.min().item():.6f}')
    print(f'  max : {model_test.cpd.U1.max().item():.6f}')
    print()

    print('U2 stats:')
    print(f'  NaNs: {torch.isnan(model_test.cpd.U2).sum().item()}')
    print(f'  min : {model_test.cpd.U2.min().item():.6f}')
    print(f'  max : {model_test.cpd.U2.max().item():.6f}')
    print()

    # Check which rows of X contain NaN
    nan_rows_s = torch.isnan(s).any(dim=1)
    nan_rows_t = torch.isnan(t).any(dim=1)
    print(f'Rows with NaN in s: {nan_rows_s.sum().item():,}')
    print(f'Rows with NaN in t: {nan_rows_t.sum().item():,}')
    print()

    # Do the NaN rows in X match our known problem pixels?
    print(f'Overlap with ~valid_mask: '
          f'{(nan_rows_s & ~mask).sum().item():,}')
    print(f'NaN rows NOT in ~mask: '
          f'{(nan_rows_s & mask).sum().item():,}')
# Out:
# s (spectral input) stats:
#   NaNs: 264630
#   Infs: 0
#   min : -2.980037
#   max : 6.400317
#
# t (topo input) stats:
#   NaNs: 52926
#   Infs: 0
#   min : -8910063172709478931354728238298431488.000000
#   max : 7.085165
#
# U1 stats:
#   NaNs: 0
#   min : -1.341589
#   max : 0.575651
#
# U2 stats:
#   NaNs: 0
#   min : -0.936096
#   max : 0.929923
#
# Rows with NaN in s: 52,926
# Rows with NaN in t: 52,926
#
# Overlap with ~valid_mask: 52,926
# NaN rows NOT in ~mask: 0

# %%
with torch.no_grad():
    t = X[:, 5:]
    
    # Find which column contains the extreme value
    print('Per-column min in t:')
    col_names = ['elevation', 'slope', 'aspect_sin', 'aspect_cos',
                 'curvature', 'log_accum', 'panchromatic', 'lwir']
    for i, name in enumerate(col_names):
        col = t[:, i]
        finite = col[torch.isfinite(col)]
        print(f'  {name:<14}: min={col.min().item():>15.4f}  '
              f'max={col.max().item():>12.4f}  '
              f'NaNs={torch.isnan(col).sum().item()}')
# Out:
# Per-column min in t:
#   elevation     : min=        -1.2983  max=      3.3008  NaNs=0
#   slope         : min=        -1.5524  max=      6.6176  NaNs=0
#   aspect_sin    : min=        -1.3858  max=      1.4202  NaNs=0
#   aspect_cos    : min=        -1.5944  max=      1.2921  NaNs=0
#   curvature     : min=        -2.9208  max=      4.0934  NaNs=0
#   log_accum     : min=-8910063172709478931354728238298431488.0000  max=      7.0852  NaNs=0
#   panchromatic  : min=        -2.0232  max=      3.3054  NaNs=0
#   lwir          : min=            nan  max=         nan  NaNs=52926

# %%
# use to determine lambdas

with torch.no_grad():
    A_test = model(X)
    
    LA_elev   = torch.sparse.mm(L_elev_t,   A_test)
    LA_aspect = torch.sparse.mm(L_aspect_t, A_test)
    LA_ddem   = torch.sparse.mm(L_ddem_t,   A_test)
    
    raw_elev   = torch.sum(A_test * LA_elev).item()   / A_test.shape[0]
    raw_aspect = torch.sum(A_test * LA_aspect).item() / A_test.shape[0]
    raw_ddem   = torch.sum(A_test * LA_ddem).item()   / A_test.shape[0]
    raw_band   = model.band_regularization(L_band_tens).item()
    
    A_valid = A_test[mask]
    R_valid = R_tens[mask]
    R_pred  = A_valid @ (E_tens / 21)
    raw_recon = torch.sum((R_valid - R_pred)**2).item() / mask.sum().item()
    
    print('Unweighted loss term magnitudes:')
    print(f'  recon          : {raw_recon:.6f}')
    print(f'  spatial_elev   : {raw_elev:.6f}')
    print(f'  spatial_aspect : {raw_aspect:.6f}')
    print(f'  spatial_ddem   : {raw_ddem:.6f}')
    print(f'  band           : {raw_band:.6f}')
    print()
    print('To balance all terms with recon as reference:')
    print(f'  lam_elev   ~ {raw_recon/raw_elev:.4f}')
    print(f'  lam_aspect ~ {raw_recon/raw_aspect:.4f}')
    print(f'  lam_ddem   ~ {raw_recon/raw_ddem:.4f}')
    print(f'  lam_band   ~ {raw_recon/raw_band:.6f}')
# Out:
# Unweighted loss term magnitudes:
#   recon          : 0.094565
#   spatial_elev   : 0.094527
#   spatial_aspect : 0.144124
#   spatial_ddem   : 0.121313
#   band           : 6.815396
#
# To balance all terms with recon as reference:
#   lam_elev   ~ 1.0004
#   lam_aspect ~ 0.6561
#   lam_ddem   ~ 0.7795
#   lam_band   ~ 0.013875

# %%
# isolate the high time bands
import time
import torch.profiler

with torch.no_grad():
    t0 = time.time()
    A_test = model(X)
    print(f'Forward pass: {time.time()-t0:.2f}s')

    t0 = time.time()
    LA = torch.sparse.mm(L_elev_t, A_test)
    print(f'One sparse mm: {time.time()-t0:.2f}s')

    t0 = time.time()
    A_valid = A_test[mask]
    R_valid = R_tens[mask]
    R_pred  = A_valid @ (E_tens / 21)
    loss_recon = torch.sum((R_valid - R_pred)**2) / mask.sum()
    print(f'Reconstruction loss: {time.time()-t0:.2f}s')

    t0 = time.time()
    loss_spatial = torch.sum(A_test * LA) / A_test.shape[0]
    print(f'Spatial loss computation: {time.time()-t0:.2f}s')
# Out:
# Forward pass: 0.38s
# One sparse mm: 0.04s
# Reconstruction loss: 0.08s
# Spatial loss computation: 0.00s

# %% [markdown]
# # Save trained model weights
# torch.save({
#     'model_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'epoch': 100,
#     'history': history,
#     'hyperparams': {
#         'D_s': 5, 'D_t': 7, 'D_out': 32,
#         'R': 8, 'D_attn': 16, 'k': 21,
#         'lr': 1e-3,
#         'lam_elev': 1.0, 'lam_aspect': 0.65,
#         'lam_ddem': 0.78, 'lam_band': 0.014
#     }
# }, 'data/graftn_checkpoint_ep100.pt')
#
# print('saved')

# %%
### post first training run ###
### load existing model     ###

# %%
# load checkpointed model
checkpoint = torch.load('data/graftn_checkpoint_ep100.pt',
                        map_location=device)

hp = checkpoint['hyperparams']
model = GRAFTN(
    D_s    = hp['D_s'],
    D_t    = hp['D_t'],
    D_out  = hp['D_out'],
    R      = hp['R'],
    D_attn = hp['D_attn'],
    k      = hp['k']
).to(device)

model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

history     = checkpoint['history']
start_epoch = checkpoint['epoch']

print(f'Restored from epoch {start_epoch}')
print(f'Last total loss : {history["total"][-1]:.6f}')
print(f'Last recon      : {history["recon"][-1]:.6f}')
print(f'Last spatial    : {history["spatial"][-1]:.6f}')
print(f'Last band       : {history["band"][-1]:.6f}')
# Out:
# Restored from epoch 100
# Last total loss : 0.231614
# Last recon      : 0.085852
# Last spatial    : 0.094514
# Last band       : 0.051248

# %%
### explore current model state ###
## as scientific instrument     ###
## rather than keep chasing lower losses ##

# %%
### inference 
model.eval()

with torch.no_grad():
    A = model(X)                       # (N, k) memberships

    A_valid  = A[mask]                 # (N_valid, k)
    R_valid  = R_tens[mask]            # (N_valid, 5)
    R_pred   = A_valid @ (E_tens / 21) # (N_valid, 5)

    # per-pixel residual: squared error summed across bands
    residuals = ((R_valid - R_pred)**2).sum(dim=1)  # (N_valid,)

    # and per-band residuals
    per_band_resid = (R_valid - R_pred)**2          # (N_valid,5)

# move to numpy for analysis
A_np         = A.cpu().numpy()                      # (N,k)
A_valid_np   = A_valid.cpu().numpy()                # (N_valid, k)
R_valid_np   = R_valid.cpu().numpy()
R_pred_np    = R_pred.cpu().numpy()
resid_np     = residuals.cpu().numpy()              # (N_valid,)

# valid pixel indices in the full node array
valid_idx    = np.where(mask.cpu().numpy())[0]      # (N_valid,)

print(f'A matrix         : {A_np.shape}')
print(f'A_valid          : {A_valid_np.shape}')
print(f'Residuals        : {resid_np.shape}')
print()
print(f'Membership stats (all pixels):')
print(f'  min  : {A_np.min():.4f}')
print(f'  max  : {A_np.max():.4f}')
print(f'  mean : {A_np.mean():.4f}')
print()
print(f'Residual stats (valid pixels):')
print(f'  min  : {resid_np.min():.6f}')
print(f'  max  : {resid_np.max():.6f}')
print(f'  mean : {resid_np.mean():.6f}')
print(f'  p50  : {np.percentile(resid_np, 50):.6f}')
print(f'  p90  : {np.percentile(resid_np, 90):.6f}')
print(f'  p95  : {np.percentile(resid_np, 95):.6f}')
print(f'  p99  : {np.percentile(resid_np, 99):.6f}')
# Out:
# A matrix         : (2041172, 21)
# A_valid          : (1988246, 21)
# Residuals        : (1988246,)
#
# Membership stats (all pixels):
#   min  : 0.1732
#   max  : 0.8814
#   mean : 0.4643
#
# Residual stats (valid pixels):
#   min  : 0.000185
#   max  : 1.983831
#   mean : 0.085662
#   p50  : 0.052011
#   p90  : 0.205225
#   p95  : 0.296725
#   p99  : 0.499995

# %%
valid_c = np.load('data/valid_c.npy')
valid_r = np.load('data/valid_r.npy')
print(f'valid_r length: {len(valid_r)}')
# Out:
# valid_r length: 2041172

# %%
# Raster coordinates of spectrally valid pixels
vr = valid_r[valid_idx]   # raster rows for valid pixels
vc = valid_c[valid_idx]   # raster cols for valid pixels

NROWS = 1875   # height, north-south extent
NCOLS = 1957   # width,  east-west extent
RES_M = 1.017  # pixel size in metres

# load and inspect
arr = np.load('data/node_features_topo.npy', allow_pickle=False)

# Percentile thresholds
p50  = np.percentile(resid_np, 50)
p90  = np.percentile(resid_np, 90)
p99  = np.percentile(resid_np, 99)

thresholds = [0, p50, p90, p99, np.inf]
labels = [
    f'Well fit  (< {p50:.3f})',
    f'Moderate  ({p50:.3f} – {p90:.3f})',
    f'Poor      ({p90:.3f} – {p99:.3f})',
    f'Very poor (> {p99:.3f})',
]
colors_cat = ['steelblue', 'goldenrod', 'darkorange', 'crimson']

# Build one canvas per category -- 1 where in category, nan elsewhere
canvases = []
for lo, hi in zip(thresholds[:-1], thresholds[1:]):
    canvas = np.full((NROWS, NCOLS), np.nan)
    in_cat = (resid_np >= lo) & (resid_np < hi)
    canvas[vr[in_cat], vc[in_cat]] = 1.0
    canvases.append(canvas)

# Also build continuous residual canvas for context
resid_canvas = np.full((NROWS, NCOLS), np.nan)
resid_canvas[vr, vc] = resid_np

# Plot -- 2 rows x 3 cols
# Top row: well fit, moderate, poor, very poor
# Bottom left: continuous residual map
# Bottom right: elevation for geographic context
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

# Category plots
for i, (canvas, label, color) in enumerate(
        zip(canvases, labels, colors_cat)):
    from matplotlib.colors import ListedColormap
    cmap_cat = ListedColormap([color])
    axes[i].imshow(np.where(~np.isnan(resid_canvas), 0.5, np.nan),
                   cmap='Greys', vmin=0, vmax=1,
                   interpolation='nearest', alpha=0.3)
    axes[i].imshow(canvas, cmap=cmap_cat,
                   vmin=0.9, vmax=1.1,
                   interpolation='nearest')
    count = int((resid_np >= thresholds[i]) & 
                (resid_np < thresholds[i+1])).sum() \
            if False else int(np.sum(
                (resid_np >= thresholds[i]) & 
                (resid_np < thresholds[i+1])))
    axes[i].set_title(f'{label}\n({count:,} pixels)', fontsize=10)
    axes[i].axis('off')

# Continuous residual map
im = axes[4].imshow(resid_canvas,
                    cmap='YlOrRd',
                    vmin=0,
                    vmax=np.percentile(resid_np, 99),
                    interpolation='nearest')
axes[4].set_title('Residual magnitude\n(clipped at p99)', fontsize=10)
axes[4].axis('off')
plt.colorbar(im, ax=axes[4], fraction=0.046)

# Elevation for geographic context
elev_canvas = np.full((NROWS, NCOLS), np.nan)
elev_canvas[valid_r, valid_c] = arr[:, 0]
axes[5].imshow(elev_canvas, cmap='terrain', interpolation='nearest')
axes[5].set_title('Elevation (reference)', fontsize=10)
axes[5].axis('off')

plt.suptitle('GRAFTN Reconstruction Residuals — Spatial Distribution',
             fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('residual_maps.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved residual_maps.png')
# Out:
# Saved residual_maps.png

# %%
## analyze endmember-wise statistics ##
import pandas as pd

em_df = pd.read_csv('data/canwell_endmembers_selected.csv')

print(f'Shape: {em_df.shape}')
print(f'Columns: {em_df.columns.tolist()}')
print()
print(em_df[['filename', 'material', 'spectrometer']].to_string())
print()

# Endmember names from the dataframe
em_names = em_df['material'].tolist()
em_files = em_df['filename'].tolist()

# More descriptive labels for plotting
em_labels = [
    'Hornblende',      # 0
    'Muscovite',       # 1
    'E.Spruce',        # 2
    'Epidote',         # 3
    'Goeth+Jar',       # 4
    'Goethite',        # 5
    'Dry Grass',       # 6
    'Jarosite',        # 7
    'Lichen Acaro',    # 8
    'Lichen Xanth-P',  # 9
    'Lichen Xanth-O',  # 10
    'Snow clean',      # 11
    'Slush 1',         # 12
    'Slush 2',         # 13
    'Glacial Algae',   # 14
    'Serpentine',      # 15
    'Willow-Sedge',    # 16
    'Dead Willow',     # 17
    'Green Willow',    # 18
    'Sedge',           # 19
    'Ice',             # 20
]

# Per-endmember statistics over valid pixels only
print(f'{"idx":>4}  {"Endmember":>16}  {"Min":>7}  {"Max":>7}  '
      f'{"Mean":>7}  {"Std":>7}  {"p50":>7}  {"p90":>7}  {"p99":>7}')
print('-' * 80)

em_stats = {}
for i, name in enumerate(em_labels):
    col = A_valid_np[:, i]
    stats = {
        'min'  : col.min(),
        'max'  : col.max(),
        'mean' : col.mean(),
        'std'  : col.std(),
        'p50'  : np.percentile(col, 50),
        'p90'  : np.percentile(col, 90),
        'p95'  : np.percentile(col, 95),
        'p99'  : np.percentile(col, 99),
    }
    em_stats[i] = stats
    print(f'{i:>4}  {name:>16}  '
          f'{stats["min"]:>7.4f}  {stats["max"]:>7.4f}  '
          f'{stats["mean"]:>7.4f}  {stats["std"]:>7.4f}  '
          f'{stats["p50"]:>7.4f}  {stats["p90"]:>7.4f}  '
          f'{stats["p99"]:>7.4f}')
# Out:
# Shape: (21, 8)
# Columns: ['filename', 'material', 'spectrometer', 'Blue_475', 'Green_560', 'Red_668', 'RedEdge_717', 'NIR_842']
#
#                                                  filename                material spectrometer
# 0             splib07a_Hornblende_HS16.3B_ASDFRb_AREF.txt              Hornblende          ASD
# 1             splib07a_Muscovite_HS146.3B_ASDFRa_AREF.txt               Muscovite          ASD
# 2   splib07a_Engelmann-Spruce_ES-Needls-1_ASDFRa_AREF.txt        Engelmann-Spruce          ASD
# 3       splib07a_Epidote_GDS26.a_75-200um_ASDNGb_AREF.txt                 Epidote          ASD
# 4    splib07a_Goeth+qtz.5+Jarosite.5_AMX11_BECKb_AREF.txt  Goeth+qtz.5+Jarosite.5         BECK
# 5    splib07a_Goethite_Phyllite_CU91-236A_ASDFRb_AREF.txt                Goethite          ASD
# 6        splib07a_Grass_Golden_Dry_GDS480_ASDFRa_AREF.txt                   Grass          ASD
# 7      splib07a_Jarosite_Rhyolite_CU91-20A_BECKa_AREF.txt                Jarosite         BECK
# 8            splib07a_Lichen_Acarospora-1_ASDFRb_AREF.txt                  Lichen          ASD
# 9        splib07a_Lichen_Xanthoparmelia-1_ASDFRb_AREF.txt                  Lichen          ASD
# 10            splib07a_Lichen_Xanthoria-1_ASDFRb_AREF.txt                  Lichen          ASD
# 11          splib07a_Melting_snow_mSnw01a_ASDFRa_AREF.txt                 Melting          ASD
# 12   splib07a_Melting_snow_mSnw09_(slush)_ASDFRa_AREF.txt                 Melting          ASD
# 13   splib07a_Melting_snow_mSnw16_(slush)_ASDFRa_AREF.txt                 Melting          ASD
# 14  splib07a_Red_Coated_Algea_Water_RCAW1_ASDFRa_AREF.txt                     Red          ASD
# 15             splib07a_Serpentine_HS8.3B_ASDFRc_AREF.txt              Serpentine          ASD
# 16    splib07a_Willow-Sedge-Mix_YNP-WS-1_AVIRISb_RTGC.txt        Willow-Sedge-Mix       AVIRIS
# 17    splib07a_Willow_Dead_FluvTailSite_A_ASDFRa_AREF.txt                  Willow          ASD
# 18              splib07a_Willow_YNP-WI-1_AVIRISb_RTGC.txt                  Willow       AVIRIS
# 19               splib07a_Sedge_YNP-SE-1_AVIRISb_RTGC.txt                   Sedge       AVIRIS
# 20                           synthetic_H2O_Ice_literature                     Ice   literature
#
#  idx         Endmember      Min      Max     Mean      Std      p50      p90      p99
# --------------------------------------------------------------------------------
#    0        Hornblende   0.1732   0.6003   0.3298   0.0340   0.3278   0.3729   0.4242
#    1         Muscovite   0.2825   0.7267   0.5245   0.0873   0.5113   0.6523   0.6897
#    2          E.Spruce   0.1983   0.6201   0.3775   0.0731   0.3693   0.4823   0.5379
#    3           Epidote   0.2840   0.7376   0.4568   0.0328   0.4596   0.4938   0.5247
#    4         Goeth+Jar   0.2619   0.7872   0.5369   0.0916   0.5315   0.6633   0.7019
#    5          Goethite   0.2057   0.6718   0.4345   0.0928   0.4304   0.5642   0.6165
#    6         Dry Grass   0.2343   0.7581   0.4109   0.0485   0.4027   0.4804   0.5247
#    7          Jarosite   0.2502   0.7257   0.4623   0.0749   0.4491   0.5701   0.6199
#    8      Lichen Acaro   0.2552   0.7819   0.5167   0.1020   0.5155   0.6543   0.7050
#    9    Lichen Xanth-P   0.2769   0.6492   0.4250   0.0781   0.4144   0.5402   0.5980
#   10    Lichen Xanth-O   0.2653   0.6907   0.4182   0.0532   0.4095   0.4979   0.5338
#   11        Snow clean   0.2305   0.8282   0.6065   0.1126   0.6034   0.7637   0.8041
#   12           Slush 1   0.2757   0.8285   0.5885   0.1248   0.5874   0.7605   0.7981
#   13           Slush 2   0.2128   0.6414   0.4145   0.0584   0.4130   0.4969   0.5415
#   14     Glacial Algae   0.2706   0.6369   0.4402   0.0573   0.4312   0.5259   0.5621
#   15        Serpentine   0.2864   0.6796   0.4790   0.0749   0.4783   0.5845   0.6253
#   16      Willow-Sedge   0.2201   0.7343   0.3951   0.0688   0.3958   0.4898   0.5411
#   17       Dead Willow   0.2122   0.6517   0.4463   0.0738   0.4371   0.5545   0.6118
#   18      Green Willow   0.2928   0.6983   0.4610   0.0348   0.4580   0.5090   0.5426
#   19             Sedge   0.2196   0.6932   0.4389   0.0533   0.4420   0.5066   0.5495
#   20               Ice   0.2762   0.8814   0.6444   0.1389   0.6464   0.8256   0.8573

# %%
"""
Ice (mean=0.644, p99=0.857)
Snow clean (mean=0.607, p99=0.804)
Slush 1 (mean=0.589, p99=0.798) 
highest-membership endmembers -- 
striking for an August terminus survey
"""


# Indices for the three snow/ice endmembers
ice_idx   = 20
snow_idx  = 11
slush_idx = 12

# Build raster canvases
def membership_canvas(A_valid_np, em_idx, valid_idx, valid_r, valid_c, nrows, ncols):
    canvas = np.full((nrows, ncols), np.nan)
    vr = valid_r[valid_idx]
    vc = valid_c[valid_idx]
    canvas[vr, vc] = A_valid_np[:, em_idx]
    return canvas

ice_canvas   = membership_canvas(A_valid_np, ice_idx,   valid_idx, valid_r, valid_c, NROWS, NCOLS)
snow_canvas  = membership_canvas(A_valid_np, snow_idx,  valid_idx, valid_r, valid_c, NROWS, NCOLS)
slush_canvas = membership_canvas(A_valid_np, slush_idx, valid_idx, valid_r, valid_c, NROWS, NCOLS)

# Shared color scale across all three for direct comparison
vmin = min(np.nanmin(ice_canvas), np.nanmin(snow_canvas), np.nanmin(slush_canvas))
vmax = max(np.nanmax(ice_canvas), np.nanmax(snow_canvas), np.nanmax(slush_canvas))

fig, axes = plt.subplots(1, 3, figsize=(18, 7))

for ax, canvas, label, cmap in zip(
    axes,
    [ice_canvas, snow_canvas, slush_canvas],
    [f'Ice\n(mean={em_stats[ice_idx]["mean"]:.3f}, std={em_stats[ice_idx]["std"]:.3f})',
     f'Snow clean\n(mean={em_stats[snow_idx]["mean"]:.3f}, std={em_stats[snow_idx]["std"]:.3f})',
     f'Slush 1\n(mean={em_stats[slush_idx]["mean"]:.3f}, std={em_stats[slush_idx]["std"]:.3f})'],
    ['Blues', 'Blues', 'Blues']
):
    im = ax.imshow(canvas, cmap=cmap, vmin=vmin, vmax=vmax,
                   interpolation='nearest')
    ax.set_title(label, fontsize=11)
    ax.axis('off')
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

plt.suptitle('Snow/Ice Endmember Memberships — GRAFTN')
plt.tight_layout()
plt.savefig('membership_snow_ice.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_snow_ice.png')
# Out:
# Saved membership_snow_ice.png

# %%
### ice vs slush 2 ####
slush2_idx = 13

ice_canvas   = membership_canvas(A_valid_np, ice_idx,    valid_idx, valid_r, valid_c, NROWS, NCOLS)
slush2_canvas = membership_canvas(A_valid_np, slush2_idx, valid_idx, valid_r, valid_c, NROWS, NCOLS)

# Difference map: Ice - Slush2
# Positive = Ice dominates, Negative = Slush2 dominates
diff_canvas = ice_canvas - slush2_canvas

fig, axes = plt.subplots(1, 3, figsize=(18, 7))

# Shared scale for Ice and Slush2
vmin = min(np.nanmin(ice_canvas), np.nanmin(slush2_canvas))
vmax = max(np.nanmax(ice_canvas), np.nanmax(slush2_canvas))

# Ice
im0 = axes[0].imshow(ice_canvas, cmap='Blues',
                     vmin=vmin, vmax=vmax,
                     interpolation='nearest')
axes[0].set_title(f'Ice\n(mean={em_stats[ice_idx]["mean"]:.3f}, '
                  f'std={em_stats[ice_idx]["std"]:.3f})', fontsize=14)
axes[0].axis('off')
plt.colorbar(im0, ax=axes[0], fraction=0.046)

# Slush 2
im1 = axes[1].imshow(slush2_canvas, cmap='Blues',
                     vmin=vmin, vmax=vmax,
                     interpolation='nearest')
axes[1].set_title(f'Slush 2\n(mean={em_stats[slush2_idx]["mean"]:.3f}, '
                  f'std={em_stats[slush2_idx]["std"]:.3f})', fontsize=14)
axes[1].axis('off')
plt.colorbar(im1, ax=axes[1], fraction=0.046)

# Difference
vdiff = np.nanpercentile(np.abs(diff_canvas), 98)
im2 = axes[2].imshow(diff_canvas, cmap='RdBu',
                     vmin=-vdiff, vmax=vdiff,
                     interpolation='nearest')
axes[2].set_title('Ice minus Slush 2\n(blue=Ice dominates, red=Slush2 dominates)',
                  fontsize=14)
axes[2].axis('off')
plt.colorbar(im2, ax=axes[2], fraction=0.046)

plt.suptitle('Ice vs Slush 2 Membership Comparison — GRAFTN', fontsize=15)
plt.tight_layout()
plt.savefig('membership_ice_vs_slush2.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_ice_vs_slush2.png')
# Out:
# Saved membership_ice_vs_slush2.png

# %%
### three lichens membership bands ###
lichen_indices = [8, 9, 10]
lichen_labels  = ['Lichen Acarospora\n(crustose, on rock)',
                  'Lichen Xanthoparmelia\n(foliose, on moraine)',
                  'Lichen Xanthoria\n(orange, distinctive)']

canvases = [membership_canvas(A_valid_np, i, valid_idx, valid_r, valid_c, NROWS, NCOLS)
            for i in lichen_indices]

# Shared color scale
vmin = min(np.nanmin(c) for c in canvases)
vmax = max(np.nanmax(c) for c in canvases)

fig, axes = plt.subplots(1, 3, figsize=(18, 7))

for ax, canvas, idx, label in zip(axes, canvases, lichen_indices, lichen_labels):
    im = ax.imshow(canvas, cmap='YlGn',
                   vmin=vmin, vmax=vmax,
                   interpolation='nearest')
    ax.set_title(f'{label}\nmean={em_stats[idx]["mean"]:.3f}  '
                 f'std={em_stats[idx]["std"]:.3f}  '
                 f'p99={em_stats[idx]["p99"]:.3f}', fontsize=14)
    ax.axis('off')
    plt.colorbar(im, ax=ax, fraction=0.046)

plt.suptitle('Lichen Endmember Memberships — GRAFTN', fontsize=15)
plt.tight_layout()
plt.savefig('membership_lichens.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_lichens.png')
# Out:
# Saved membership_lichens.png

# %%
### memberships encoding 'spectral similarity' ###
### not 'material identity'                    ###
### investigate pairwise correlation           ###

# %%
# Correlation matrix of all 21 membership columns
# over spectrally valid pixels
C_mem = np.corrcoef(A_valid_np.T)   # (21, 21)

fig, ax = plt.subplots(figsize=(13, 11))

im = ax.imshow(C_mem, cmap='RdBu_r', vmin=-1, vmax=1,
               interpolation='nearest')

ax.set_xticks(range(21))
ax.set_yticks(range(21))
ax.set_xticklabels(em_labels, rotation=45, ha='right', fontsize=10)
ax.set_yticklabels(em_labels, fontsize=10)

# Annotate with correlation values
for i in range(21):
    for j in range(21):
        ax.text(j, i, f'{C_mem[i,j]:.2f}',
                ha='center', va='center',
                fontsize=6,
                color='white' if abs(C_mem[i,j]) > 0.6 else 'black')

plt.colorbar(im, ax=ax, fraction=0.046)
plt.suptitle('Endmember Membership Correlation Matrix — GRAFTN', fontsize=15)
plt.tight_layout()
plt.savefig('membership_correlation.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_correlation.png')

# Print the most strongly correlated pairs
print('Strongly correlated pairs (|r| > 0.7):')
print(f'{"Endmember A":>20}  {"Endmember B":>20}  {"r":>7}')
print('-' * 52)
for i in range(21):
    for j in range(i+1, 21):
        if abs(C_mem[i,j]) > 0.7:
            print(f'{em_labels[i]:>20}  {em_labels[j]:>20}  '
                  f'{C_mem[i,j]:>7.4f}')
# Out:
# Saved membership_correlation.png
# Strongly correlated pairs (|r| > 0.7):
#          Endmember A           Endmember B        r
# ----------------------------------------------------
#            Muscovite              E.Spruce   0.8178
#            Muscovite             Goeth+Jar   0.9310
#            Muscovite              Goethite   0.8899
#            Muscovite             Dry Grass   0.8002
#            Muscovite              Jarosite   0.9067
#            Muscovite          Lichen Acaro   0.9195
#            Muscovite        Lichen Xanth-P   0.8871
#            Muscovite        Lichen Xanth-O   0.9083
#            Muscovite            Snow clean   0.9536
#            Muscovite               Slush 1   0.9269
#            Muscovite               Slush 2   0.7346
#            Muscovite         Glacial Algae   0.9139
#            Muscovite            Serpentine   0.9142
#            Muscovite          Willow-Sedge   0.7838
#            Muscovite           Dead Willow   0.8968
#            Muscovite                   Ice   0.9468
#             E.Spruce             Goeth+Jar   0.8324
#             E.Spruce              Goethite   0.9003
#             E.Spruce             Dry Grass   0.7980
#             E.Spruce              Jarosite   0.8388
#             E.Spruce          Lichen Acaro   0.8580
#             E.Spruce        Lichen Xanth-P   0.9257
#             E.Spruce        Lichen Xanth-O   0.8693
#             E.Spruce            Snow clean   0.7864
#             E.Spruce               Slush 1   0.8625
#             E.Spruce               Slush 2   0.8664
#             E.Spruce         Glacial Algae   0.9100
#             E.Spruce            Serpentine   0.8015
#             E.Spruce          Willow-Sedge   0.9072
#             E.Spruce           Dead Willow   0.8368
#             E.Spruce                 Sedge   0.8004
#             E.Spruce                   Ice   0.8072
#            Goeth+Jar              Goethite   0.8644
#            Goeth+Jar             Dry Grass   0.7908
#            Goeth+Jar              Jarosite   0.8568
#            Goeth+Jar          Lichen Acaro   0.9175
#            Goeth+Jar        Lichen Xanth-P   0.8641
#            Goeth+Jar        Lichen Xanth-O   0.8690
#            Goeth+Jar            Snow clean   0.9096
#            Goeth+Jar               Slush 1   0.9379
#            Goeth+Jar               Slush 2   0.7662
#            Goeth+Jar         Glacial Algae   0.8895
#            Goeth+Jar            Serpentine   0.8978
#            Goeth+Jar          Willow-Sedge   0.7537
#            Goeth+Jar           Dead Willow   0.7985
#            Goeth+Jar                   Ice   0.9559
#             Goethite             Dry Grass   0.7944
#             Goethite              Jarosite   0.8142
#             Goethite          Lichen Acaro   0.9074
#             Goethite        Lichen Xanth-P   0.9449
#             Goethite        Lichen Xanth-O   0.9157
#             Goethite            Snow clean   0.8229
#             Goethite               Slush 1   0.9322
#             Goethite               Slush 2   0.8840
#             Goethite         Glacial Algae   0.9301
#             Goethite            Serpentine   0.7971
#             Goethite          Willow-Sedge   0.9208
#             Goethite           Dead Willow   0.8598
#             Goethite                 Sedge   0.7687
#             Goethite                   Ice   0.8558
#            Dry Grass              Jarosite   0.7928
#            Dry Grass          Lichen Acaro   0.8501
#            Dry Grass        Lichen Xanth-P   0.7898
#            Dry Grass        Lichen Xanth-O   0.8004
#            Dry Grass            Snow clean   0.7539
#            Dry Grass               Slush 1   0.8184
#            Dry Grass               Slush 2   0.7004
#            Dry Grass         Glacial Algae   0.8241
#            Dry Grass            Serpentine   0.8150
#            Dry Grass          Willow-Sedge   0.7443
#            Dry Grass           Dead Willow   0.7301
#            Dry Grass                   Ice   0.8217
#             Jarosite          Lichen Acaro   0.8689
#             Jarosite        Lichen Xanth-P   0.8438
#             Jarosite        Lichen Xanth-O   0.8293
#             Jarosite            Snow clean   0.9180
#             Jarosite               Slush 1   0.8318
#             Jarosite         Glacial Algae   0.8867
#             Jarosite            Serpentine   0.8958
#             Jarosite          Willow-Sedge   0.7679
#             Jarosite           Dead Willow   0.9096
#             Jarosite                 Sedge   0.7379
#             Jarosite                   Ice   0.8765
#         Lichen Acaro        Lichen Xanth-P   0.8777
#         Lichen Acaro        Lichen Xanth-O   0.8824
#         Lichen Acaro            Snow clean   0.9029
#         Lichen Acaro               Slush 1   0.9371
#         Lichen Acaro               Slush 2   0.7846
#         Lichen Acaro         Glacial Algae   0.9120
#         Lichen Acaro            Serpentine   0.9123
#         Lichen Acaro          Willow-Sedge   0.7886
#         Lichen Acaro           Dead Willow   0.8088
#         Lichen Acaro                   Ice   0.9531
#       Lichen Xanth-P        Lichen Xanth-O   0.9152
#       Lichen Xanth-P            Snow clean   0.8390
#       Lichen Xanth-P               Slush 1   0.9261
#       Lichen Xanth-P               Slush 2   0.8776
#       Lichen Xanth-P         Glacial Algae   0.9459
#       Lichen Xanth-P            Serpentine   0.8477
#       Lichen Xanth-P          Willow-Sedge   0.9341
#       Lichen Xanth-P           Dead Willow   0.8391
#       Lichen Xanth-P                 Sedge   0.7497
#       Lichen Xanth-P                   Ice   0.8552
#       Lichen Xanth-O            Snow clean   0.8688
#       Lichen Xanth-O               Slush 1   0.9090
#       Lichen Xanth-O               Slush 2   0.8209
#       Lichen Xanth-O         Glacial Algae   0.8875
#       Lichen Xanth-O            Serpentine   0.8818
#       Lichen Xanth-O          Willow-Sedge   0.8544
#       Lichen Xanth-O           Dead Willow   0.8494
#       Lichen Xanth-O                   Ice   0.8778
#           Snow clean               Slush 1   0.9025
#           Snow clean         Glacial Algae   0.8654
#           Snow clean            Serpentine   0.9351
#           Snow clean          Willow-Sedge   0.7075
#           Snow clean           Dead Willow   0.8696
#           Snow clean                   Ice   0.9559
#              Slush 1               Slush 2   0.8542
#              Slush 1         Glacial Algae   0.9180
#              Slush 1            Serpentine   0.8967
#              Slush 1          Willow-Sedge   0.8553
#              Slush 1           Dead Willow   0.8190
#              Slush 1                   Ice   0.9487
#              Slush 2         Glacial Algae   0.8424
#              Slush 2          Willow-Sedge   0.8853
#              Slush 2           Dead Willow   0.7270
#              Slush 2                 Sedge   0.7016
#              Slush 2                   Ice   0.7275
#        Glacial Algae            Serpentine   0.8845
#        Glacial Algae          Willow-Sedge   0.8983
#        Glacial Algae           Dead Willow   0.8797
#        Glacial Algae                 Sedge   0.7756
#        Glacial Algae                   Ice   0.8811
#           Serpentine          Willow-Sedge   0.7347
#           Serpentine           Dead Willow   0.8039
#           Serpentine                   Ice   0.9404
#         Willow-Sedge           Dead Willow   0.8237
#         Willow-Sedge                 Sedge   0.7929
#         Willow-Sedge                   Ice   0.7220
#          Dead Willow                 Sedge   0.7831
#          Dead Willow                   Ice   0.7888

# %%
horn_idx  = 0
grass_idx = 6
dwill_idx = 17

canvases = [membership_canvas(A_valid_np, i, valid_idx, valid_r, valid_c, NROWS, NCOLS)
            for i in [horn_idx, grass_idx, dwill_idx]]

labels = [
    f'Hornblende\nmean={em_stats[horn_idx]["mean"]:.3f}  std={em_stats[horn_idx]["std"]:.3f}  p99={em_stats[horn_idx]["p99"]:.3f}',
    f'Dry Grass\nmean={em_stats[grass_idx]["mean"]:.3f}  std={em_stats[grass_idx]["std"]:.3f}  p99={em_stats[grass_idx]["p99"]:.3f}',
    f'Dead Willow\nmean={em_stats[dwill_idx]["mean"]:.3f}  std={em_stats[dwill_idx]["std"]:.3f}  p99={em_stats[dwill_idx]["p99"]:.3f}',
]
cmaps = ['Greys', 'YlOrBr', 'YlGn']

fig, axes = plt.subplots(1, 3, figsize=(18, 7))

for ax, canvas, label, cmap in zip(axes, canvases, labels, cmaps):
    vmin = np.nanmin(canvas)
    vmax = np.nanmax(canvas)
    im = ax.imshow(canvas, cmap=cmap, vmin=vmin, vmax=vmax,
                   interpolation='nearest')
    ax.set_title(label, fontsize=14)
    ax.axis('off')
    plt.colorbar(im, ax=ax, fraction=0.046)

plt.suptitle('Hornblende, Dry Grass, Dead Willow Memberships — GRAFTN', fontsize=15)
plt.tight_layout()
plt.savefig('membership_horn_grass_willow.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_horn_grass_willow.png')
# Out:
# Saved membership_horn_grass_willow.png

# %%
# Well-fit mask: residual < p50
well_fit = resid_np < p50   # boolean, length N_valid

# Well-fit node indices in full array
well_fit_valid_idx = valid_idx[well_fit]

# Build canvases showing only well-fit pixels
def membership_canvas_masked(A_valid_np, em_idx, node_mask,
                              valid_idx, valid_r, valid_c, nrows, ncols):
    """
    Like membership_canvas but only paints pixels where node_mask is True.
    node_mask : boolean array of length N_valid
    """
    canvas = np.full((nrows, ncols), np.nan)
    idx = valid_idx[node_mask]
    vr  = valid_r[idx]
    vc  = valid_c[idx]
    canvas[vr, vc] = A_valid_np[node_mask, em_idx]
    return canvas

canvases_wf = [
    membership_canvas_masked(A_valid_np, i, well_fit,
                             valid_idx, valid_r, valid_c, NROWS, NCOLS)
    for i in [horn_idx, grass_idx, dwill_idx]
]

labels = [
    f'Hornblende\nmean={A_valid_np[well_fit, horn_idx].mean():.3f}  '
    f'std={A_valid_np[well_fit, horn_idx].std():.3f}',
    f'Dry Grass\nmean={A_valid_np[well_fit, grass_idx].mean():.3f}  '
    f'std={A_valid_np[well_fit, grass_idx].std():.3f}',
    f'Dead Willow\nmean={A_valid_np[well_fit, dwill_idx].mean():.3f}  '
    f'std={A_valid_np[well_fit, dwill_idx].std():.3f}',
]
cmaps = ['Greys', 'YlOrBr', 'YlGn']

fig, axes = plt.subplots(1, 3, figsize=(18, 7))

for ax, canvas, label, cmap in zip(axes, canvases_wf, labels, cmaps):
    vmin = np.nanpercentile(canvas, 1)
    vmax = np.nanpercentile(canvas, 99)
    im = ax.imshow(canvas, cmap=cmap, vmin=vmin, vmax=vmax,
                   interpolation='nearest')
    ax.set_title(label, fontsize=14)
    ax.axis('off')
    plt.colorbar(im, ax=ax, fraction=0.046)

plt.suptitle('Hornblende, Dry Grass, Dead Willow — Well-fit Pixels Only\n'
             f'({well_fit.sum():,} pixels, residual < {p50:.3f})',
             fontsize=15)
plt.tight_layout()
plt.savefig('membership_horn_grass_willow_wellfit.png', dpi=130, bbox_inches='tight')
plt.show()
print('Saved membership_horn_grass_willow_wellfit.png')
# Out:
# Saved membership_horn_grass_willow_wellfit.png
