# %%
import geopandas as gpd

# %%
bluffs = gpd.read_file(r"/mnt/c/Users/samuel.n.walters/Downloads/Maine_Coastal_Landslides.kml")

# %%
print("Shape:", bluffs.shape)
print("\nColumns:", list(bluffs.columns))
print("\nFirst few rows:")
print(bluffs.head())

# Check what might indicate risk/hazard level
for col in bluffs.columns:
    if col != 'geometry':
        print(f"\n{col} unique values:")
        print(bluffs[col].value_counts())
# Out:
# Shape: (3126, 35)
#
# Columns: ['id', 'Name', 'description', 'timestamp', 'begin', 'end', 'altitudeMode', 'tessellate', 'extrude', 'visibility', 'drawOrder', 'icon', 'OBJECTID', 'QUADNAME', 'BLUFF', 'STABILITY', 'TYPE', 'LANDSLIDE', 'HAZARD', 'NEWREFID', 'COMMENTS', 'TOWN', 'GEOCODE', 'BLUFFS_PUBCODE', 'BLUFFS_AUTHOR', 'BLUFFS_PUBDATE', 'BLUFFS_TITLE', 'BLUFFS_SOURCE', 'LANDSLIDES_PUBCODE', 'LANDSLIDES_AUTHOR', 'LANDSLIDES_PUBDATE', 'LANDSLIDES_TITLE', 'LANDSLIDES_SOURCE', 'Shape__Length', 'geometry']
#
# First few rows:
#      id  Name description timestamp begin end altitudeMode  tessellate  \
# 0  None  None        None       NaT   NaT NaT         None          -1
# 1  None  None        None       NaT   NaT NaT         None          -1
# 2  None  None        None       NaT   NaT NaT         None          -1
# 3  None  None        None       NaT   NaT NaT         None          -1
# 4  None  None        None       NaT   NaT NaT         None          -1
#
# ...
